# %%
import numpy as np
x =np.array([True, True, False])
print(x)
y =np.array([1,1,0], dtype=bool)
print(y)
# Out:
# [ True  True False]
# [ True  True False]

# %%
import numpy as np
A = np.array([1, 2, 3])
B = np.array([-1,2, 4])
print(A!=B)
print(A<B)
x = np.array([[2,3,4],[-1,-1,-1]])
y = np.array([[-2,3,5],[2,3,-7]])
print(x)
print(y)
print(x>=y) # поэлементное сравнение массивов
h = np.array([[2, 3, -4],[0, -2, 3]])
print(h)
print(h<0) # проверим какие из элементов отрицательные
x=np.array([1,2])
y=np.array([2,4])
z=np.array([2,4,3])
print(np.array_equal(x,y))
print(np.array_equal(y,z))
print(np.array_equal(y,z[:2]))
# Out:
# [ True False  True]
# [False False  True]
# [[ 2  3  4]
#  [-1 -1 -1]]
# [[-2  3  5]
#  [ 2  3 -7]]
# [[ True  True False]
#  [False False  True]]
# [[ 2  3 -4]
#  [ 0 -2  3]]
# [[False False  True]
#  [False  True False]]
# False
# False
# True

# %%
import numpy as np
z = 256
k = np.arange(0,8)
r = np.abs(z)
phi=np.angle(z)
zroot = r**(1/8)*( np.cos(phi+2.0*np.pi*k/8) + 1j*np.sin(phi+2.0*np.pi*k/8))
print(zroot<0)
print(np.isclose(np.imag(zroot),0))
print(phi)
# Out:
# [False False False  True  True  True  True False]
# [ True False False False  True False False False]
# 0.0

# %%
import numpy as np
x = np.array([0,0,1,1], dtype=bool)
y = np.array([0,1,0,1], dtype=bool)
t = np.array([1<2, 5>3])
print(' x = '+str(x))
print(' y = '+str(y))
print('x and y = '+str(x&y))
print('x or y = '+str(x|y))
print('x xor y = '+str(x^y))
print(' not x = '+str(~x))
# Out:
#  x = [False False  True  True]
#  y = [False  True False  True]
# x and y = [False False False  True]
# x or y = [False  True  True  True]
# x xor y = [False  True  True False]
#  not x = [ True  True False False]

# %%
import numpy as np
z1 = 28-4j
z2 = 20+10j
print('z1='+str(z1))
print('z2='+str(z2))
print('Both of |z_{1}|<29 and |z_{2}|<29 --> '+
str((np.abs(z1)<29) & (np.abs(z2)<29)) )
# проверим, верно ли, что модули обоих чисел меньше 29.
print('Any of |z_{1}|>32 or |z_{2}|>32 --> '+
str((np.abs(z1)>32) | (np.abs(z2)>32)) )
# верно ли, что модуль хотя бы одного из них больше 32.
# Out:
# z1=(28-4j)
# z2=(20+10j)
# Both of |z_{1}|<29 and |z_{2}|<29 --> True
# Any of |z_{1}|>32 or |z_{2}|>32 --> False

# %%
import numpy as np
z1 = 2-3j
z2 = 5+1j
print('z1='+str(z1))
print('z2='+str(z2))
print('1) Both of arg(z1)>np.pi/3 and arg(z2)<=5*np.pi/6 --> '+
str((np.angle(z1)>np.pi/3) & (np.angle(z2)<=5*np.pi/6)) )
print('2) Any of Re(3*z1 + 2*z2)<8 or Im(z1-z2)!=2 --> '+
str((np.real(3*z1 + 2*z2)<8) | (np.imag(z1-z2)!=2)) )
# Out:
# z1=(2-3j)
# z2=(5+1j)
# 1) Both of arg(z1)>np.pi/3 and arg(z2)<=5*np.pi/6 --> False
# 2) Any of Re(3*z1 + 2*z2)<8 or Im(z1-z2)!=2 --> True

# %%
import numpy as np
A = np.array([1,2,3,4])
print('A '+str(A))
print('A>=2 '+str(A[A>=2]))
# выбираем элементы из массива A, которые >= 2
L = np.array([0,1,1,0], dtype=bool)
B = A[L]
# прочитаем элементы с помощью логических индексов L
A[L] = -5
# перезапишем на эти позиции в массиве А новые значения
print('B=A(L) '+str(B))
print('A(L)=-5 '+str(A))
# Out:
# A [1 2 3 4]
# A>=2 [2 3 4]
# B=A(L) [2 3]
# A(L)=-5 [ 1 -5 -5  4]

# %%
import numpy as np
k = np.arange(1,9,1)
z = np.power((1+3j),k)
B = np.real(z)>2
print('Re(z)>=2 '+str(z[B]))
B = np.imag(z) <= np.real(z)
print('Im(z)<= Re(z) '+str(z[B]))
# Out:
# Re(z)>=2 [ 28. -96.j 316. -12.j 352.+936.j]
# Im(z)<= Re(z) [ 28.-96.j 316.-12.j]

# %%
import numpy as np
k = np.arange(1,10,1)
z = 3-k*1j
B = (np.abs(z)> 4) & (np.abs(z) <=7)
z[B]=0
print(str(z))
# Out:
# [3.-1.j 3.-2.j 0.+0.j 0.+0.j 0.+0.j 0.+0.j 3.-7.j 3.-8.j 3.-9.j]

# %%
import numpy as np
import numpy.random as rng
import matplotlib.pyplot as plt
x = 3 - 6*rng.rand(10000) # 10_000 точек x на отрезке [-3;3]
y = 3 - 6*rng.rand(10000) # 10_000 точек y на отрезке [-3;3]
z = x+ 1j*y
L = (np.abs(z+1j)>=1.5) # логический индекс для отбора значений
plt.plot(x[L],y[L],'.')
plt.axis('equal')
plt.grid(True)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.title('$| z+i | \geq 1.5 $')
plt.xlabel('Re(z)')
plt.ylabel('Im(z)')
# Out:
# Text(0, 0.5, 'Im(z)')

# %%
import numpy as np
import numpy.random as rng
import matplotlib.pyplot as plt
x = 3 - 6*rng.rand(10000) # 10_000 точек x на отрезке [-3;3]
y = 3 - 6*rng.rand(10000) # 10_000 точек y на отрезке [-3;3]
z = x+ 1j*y
L = ((np.abs(z-1-1j)>=1) & (np.abs(z-1-1j)<=2)) # логический индекс для отбора значений
plt.plot(x[L],y[L],'.')
plt.axis('equal')
plt.grid(True)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.title('$1<=| z-1-i |<=2 $')
plt.xlabel('Re(z)')
plt.ylabel('Im(z)')
# Out:
# Text(0, 0.5, 'Im(z)')

# %%
import numpy as np
z = -256
k = np.arange(0,8)
zroot = np.abs(z)*(np.cos((np.angle(z)+2*np.pi*k)/8)+1j*np.sin((np.angle(z)+2*np.pi*k)/8))
np.real(zroot)<0
zroot1=np.real(zroot)
print(zroot)
print(np.real(zroot)<0)
print(zroot1)
print(np.angle(zroot1)>2*np.pi/3)
# Out:
# [ 236.51316032 +97.96695869j   97.96695869+236.51316032j
#   -97.96695869+236.51316032j -236.51316032 +97.96695869j
#  -236.51316032 -97.96695869j  -97.96695869-236.51316032j
#    97.96695869-236.51316032j  236.51316032 -97.96695869j]
# [False False  True  True  True  True False False]
# [ 236.51316032   97.96695869  -97.96695869 -236.51316032 -236.51316032
#   -97.96695869   97.96695869  236.51316032]
# [False False  True  True  True  True False False]

# %%
import numpy as np
z1 = 2-3j
z2 = 5 +1j
print('z1='+str(z1))
print('z2='+str(z2))
print('1) 5 <=|z1|<6 --> '+
str((np.abs(z1)>= 5) & (np.abs(z1) <6)))
print('2) |z1|<4 or |z2|<4 --> '+
str((np.abs(z1) <4) | (np.abs(z2) <4)) )
# Out:
# z1=(2-3j)
# z2=(5+1j)
# 1) 5 <=|z1|<6 --> False
# 2) |z1|<4 or |z2|<4 --> True

# %%
import numpy as np
k = np.arange(1,9,1)
z = np.power((1-3j),k)
B = np.real(z)>2
print('Re(z)>2 '+str(z[B]))
B = np.imag(z) <= np.real(z)
print('Im(z)<= Re(z) '+str(z[B]))
# Out:
# Re(z)>2 [ 28. +96.j 316. +12.j 352.-936.j]
# Im(z)<= Re(z) [  1.  -3.j 316. +12.j 352.-936.j]

# %%
import numpy as np
k = np.arange(1,10,1)
z = 2-k*1j
B = (np.abs(z)> 2) & (np.abs(z) <=5)
z[B]=0
print(str(z))
# Out:
# [0.+0.j 0.+0.j 0.+0.j 0.+0.j 2.-5.j 2.-6.j 2.-7.j 2.-8.j 2.-9.j]

# %%
import numpy as np
import numpy.random as rng
import matplotlib.pyplot as plt
x = 3 - 6*rng.rand(10000) # 10_000 точек x на отрезке [-3;3]
y = 3 - 6*rng.rand(10000) # 10_000 точек y на отрезке [-3;3]
z = x+ 1j*y
L = (((np.abs(np.angle(z)))>=np.pi/4) & (np.abs(z-1)<=2)) # логический индекс для отбора значений
plt.plot(x[L],y[L],'.')
plt.axis('equal')
plt.grid(True)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.title('$1<=| z-1 |<=2 $')
plt.xlabel('Re(z)')
plt.ylabel('Im(z)')
# Out:
# Text(0, 0.5, 'Im(z)')
